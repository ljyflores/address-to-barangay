# %%
import pandas as pd
import numpy as np
import string
import requests
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing & Cleaning Data

# %% [markdown]
# Description: Reads in the data and stores it in the dataframe "data", then removes all punctuations and turns stores the cleaned data into the dataframe "fix"
#
# To Do: Turn the list of addresses you receive into a csv file and update the name in the read_csv function

# %%
data = pd.read_csv("Sample Input.csv") #Here!

# %%
fix = {'stripaddress': data['stripaddress'], 'edit': data['stripaddress']}  
fix = pd.DataFrame(fix, columns = ['stripaddress', 'edit'])

# %%
fix['edit'] = [s.translate(string.punctuation) for s in fix['edit']]
fix['edit'] = [s.replace(',', ' ').replace('.',' ').replace('#',' ') for s in fix['edit']]
fix['lst'] = [s.split() for s in fix['edit']]

# %% [markdown]
# ### Columns for Lat & Long (Run Only Once!)

# %% [markdown]
# Description: Creates latitute, longitude, and address columns that will be filled in later from the Google Maps API

# %%
fix['lat']=np.repeat(None, len(fix['edit']))
fix['lng']=np.repeat(None, len(fix['edit']))
fix['add']=np.repeat(None, len(fix['edit']))

# %% [markdown]
# ### Importing Shapefiles

# %% [markdown]
# Description: Uploads shapefiles to get coordinates data for each baranggay, and creates a dataframe called "df"
#
# To Do: Change the address of the baranggay shapefile from '/Users/lorenzoflores/Desktop/LOOKUP-NCR-2ndDistrict-QuezonCity/Barangays.shp' to wherever it is stored on your computer

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(10,6))
# %matplotlib inline

shp_path = '/Users/lorenzoflores/Desktop/LOOKUP-NCR-2ndDistrict-QuezonCity/Barangays.shp' #Here!
sf = shp.Reader(shp_path, encoding='latin-1')

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %% [markdown]
# ### Subsetting Shapefiles for Quezon City

# %% [markdown]
# Description: Removes all other baranggay shapefiles from the df dataframe except for the area you choose, in order to reduce run time
#
# To Do: Change Metropolitan Manila to whichever province you're working on, run the code below to check the available provinces

# %%
#Run me to check available provinces!
set(df['NAME_1'])
# Out:
# {'Metropolitan Manila'}

# %%
df = read_shapefile(sf)
df = df[df['NAME_1']=='Metropolitan Manila'] #Here!
df = df.reset_index(drop=True)

# %% [markdown]
# ### Geotagging from Google Maps (Run Only Once!)

# %% [markdown]
# Description: Uses Google Maps to identify coordinates for each address
#
# To Do: Input your own Google API key for the geotagging API as it says below

# %%
for i in range(len(fix['edit'])):
    if i%100==0:
        print("Now on: "+str(i))
    try:
        x = fix['edit'][i]
        response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address='+
                                x+',Philippines'+'&key='+"INSERT YOUR KEY HERE IN THE QUOTATION MARKS")
        resp_json_payload = response.json()
        fix['add'][i] = resp_json_payload['results'][0]['formatted_address']
        fix['lat'][i] = resp_json_payload['results'][0]['geometry']['location']['lat']
        fix['lng'][i] = resp_json_payload['results'][0]['geometry']['location']['lng']
    except:
        print("Error on: "+str(i))
        print(fix['edit'][i])
# Out:
# Now on: 0
# Now on: 100
# Now on: 200
# Error on: 296
# 1141 SANTA RC
# Now on: 300
# Now on: 400
# Now on: 500
# Now on: 600
# Error on: 615
# 142 TARLAC ST COMMONWEALTH QUEZON CITY
# Error on: 659
# 15 BLK 52 PANTOMINA MAYOR ST LAGRO SUBD NOVALICHES QUEZON CITY
# Now on: 700
# Error on: 777
# 16-C BLK A STO  NIÑO ST   QUEZON CITY CPO  QUEZON CITY 1100
# Now on: 800
# Error on: 867
# 189 EVERLASTING ST PINGKIAN 3 ZN 1 PASONG TAMO QUEZON CITY
# Now on: 900
# Error on: 995
# 207 SECOND NORTH 2906 KING SOLOMON ST AREA C
# Error on: 996
# 207 UNIT 5 ADARNA STREET PUROK 6 COMMONWEALTH QUEZON CITY
# Now on: 1000
# Now on: 1100
# Error on: 1187
# 27 NUPAX CMPD BAGBAG NOVALICHES QUEZON CITY
# Now on: 1200
# Now on: 1300
# Error on: 1358
# 35-D PROJECT 4 ESCOPA I QUEZON CITY NCR
# Now on: 1400
# Now on: 1500
# Now on: 1600
# Now on: 1700
# Now on: 1800
# Now on: 1900
# Now on: 2000
# Now on: 2100
# Now on: 2200
# Now on: 2300
# Now on: 2400
# Error on: 2454
# B7-L14/16 P1 SILVERCREEK SUBD
# Error on: 2455
# B7-L22 PORTICO-I SUBD
# Now on: 2500
# Now on: 2600
# Now on: 2700
# Error on: 2700
# BLK 2 LOT 15 KALIGTASAN EXT  HOLY SPIRIT  HOLY SPIRIT  QUEZON CITY   NATIONA CAPITAL REGION
# Error on: 2718
# BLK 2 LT 3 TITUS VILLAS TITUS ST WEST FAIRVIEW QUEZON CITY
# Error on: 2749
# BLK 2A LOT 33 PALMERA HOMES SUBD NOVALICHES EAST QUEZON CITY
# Error on: 2792
# BLK 31 LOT 55 SALUBONG ST LAGRO SUBD NOVALICHES PROPER QUEZON CITY
# Now on: 2800
# Error on: 2833
# BLK 46 LOT 18 TATLONG HARI ST LAGRO NOVALICHES PROPER QUEZON CITY
# Now on: 2900
# Error on: 2965
# BLOCK 28 LOT 2 DIEGO SILANG ST NCE 1 BATASAN HILLS QUEZON CITY
# Now on: 3000
# Now on: 3100
# Now on: 3200
# Now on: 3300
# Now on: 3400
# Now on: 3500
# Now on: 3600
# Error on: 3667
# G-45 ABBEY RD BAGBAG NOVALICHES QUEZON CITY
# Now on: 3700
# Now on: 3800
# Now on: 3900
# Error on: 3981
# JOSE ABAD SANTOS ST STA LUCIA NOVALICHES NOVALICHES PROPER QUEZON CITY
# Now on: 4000
# Now on: 4100
# Now on: 4200
# Now on: 4300
# Error on: 4397
# LOT 25 BLK 2 SANTAN ST MALIGAYA NOVALICHES PROPER QUEZON CITY
# Now on: 4400
# Now on: 4500
# Now on: 4600
# Now on: 4700
# Now on: 4800
# Error on: 4890
# Ñ84-C ROAD 2 PAG-ASA QUEZON CITY
# Now on: 4900
# Error on: 4939
# NIÑO KID  CITY
# Error on: 4940
# NIÑO  KID  CITY
# Error on: 4981
# OAK EXT WEST FAIRVIEW QUEZON CITY
# Now on: 5000
# Now on: 5100
# Error on: 5185
# PINK CONDO TIERRA BELLA TANDANG SORA Q C   N/A  N/A  N/A
# Now on: 5200
# Now on: 5300
# Now on: 5400
# Now on: 5500
# Now on: 5600
# Error on: 5644
# SITIO PALANAS VASRA QUEZON CITY
# Error on: 5645
# SITIO PALANAS VASRA QUEZON CITY
# Now on: 5700
# Error on: 5741
# STO NIÑO ST B BAYAN QUEZON CITY
# Now on: 5800
# Now on: 5900
# Error on: 5968
# UNIT 4 ILANG ILANG ILANG ST
# Now on: 6000
# Now on: 6100

# %% [markdown]
# ### Baranggay + Address Coordinates Matching

# %% [markdown]
# Description: Identifies the baranggay to which the coordinates of the address belongs

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %% [markdown]
# Turn each baranggay in df into a polygon

# %%
df['poly']=np.repeat(None, len(df['NAME_1']))
for i in range(len(df['poly'])):   
    df['poly'][i] = Polygon(df.iloc[i,]['coords'])
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Turn each address in fix into a point

# %%
fix['pt']=np.repeat(None, len(fix['lat']))
for i in range(len(fix['lat'])):
    if fix['add'][i] is not None:
        fix['pt'][i] = Point(fix['lng'][i],fix['lat'][i])
    else:
        pass

# %% [markdown]
# Create a baranggay name column

# %%
fix['bgy']=np.repeat(None, len(fix['lat']))

# %% [markdown]
# For each point, check if it belongs to a baranggay

# %%
for i in range(len(fix['edit'])):
    if i%100==0:
        print("Now on: "+str(i))
    if fix['add'][i] is not None:
        for j in range(len(df['poly'])):
            if fix['pt'][i].within(df['poly'][j]):
                fix['bgy'][i] = df['NAME_3'][j]
                break
    if fix['bgy'][i] is None:
        print("Check: "+str(i))
        print(fix['edit'][i])
# Out:
# Now on: 0
# Check: 4
# 001 LEYTE GROUP 7 PAYATAS QUEZON CITY
# Check: 11
# 004 ZAMBOANGA ST   BAI COMPOUND  BRGY  VASRA  QUEZON CITY  N/A
# Check: 93
# 079 GINUNTUANG LANDAS FOREST HILL SANTA MONICA QUEZON CITY
# Now on: 100
# Now on: 200
# Check: 215
# 1064 A CULLEJON LIWANAG BGY 215 TONDO MANILA
# Check: 218
# 107 SAMPAGUITA EXT PAYATAS QUEZON CITY
# Check: 235
# 109 LIVERPOOL ST CLASSICA II VISTA REAL QUEZON CITY
# Check: 287
# 114 CHICO ST QUIRINO 2B PROJEC 2 ALICIA QUEZON CITY
# Check: 296
# 1141 SANTA RC
# Now on: 300
# Check: 307
# 116 BAGUIO CMPD ROAD 20 PROJECT 8 QUEZON CITY
# Check: 391
# 120 NEW YORK STREET  BRGY  CUBAO  QUEZON CITY  N/A  N/A  N/A
# Now on: 400
# Now on: 500
# Check: 547
# 137 SAINT HERMINE ST  BROOKSIDE BAGONG SILANGAN QUEZON CITY NCR
# Check: 584
# 13K BLK A STO NIÑO ST SAN ANTONIO SFDM SAN ANTONIO QUEZON CITY
# Now on: 600
# Check: 615
# 142 TARLAC ST COMMONWEALTH QUEZON CITY
# Check: 634
# 146 CAMIA ST SAN ROQUE 2 PAGASA QUEZON CITY
# Check: 659
# 15 BLK 52 PANTOMINA MAYOR ST LAGRO SUBD NOVALICHES QUEZON CITY
# Now on: 700
# Check: 758
# 165 BATINO ST  DUYAN-DUYAN QUEZON CITY NCR
# Check: 777
# 16-C BLK A STO  NIÑO ST   QUEZON CITY CPO  QUEZON CITY 1100
# Check: 785
# 17 BLK 43 CELERINA ST PALMERA SPRING II NOVALICHES PROPER QUEZON CITY
# Now on: 800
# Check: 867
# 189 EVERLASTING ST PINGKIAN 3 ZN 1 PASONG TAMO QUEZON CITY
# Check: 869
# 189 TEXAS ST UPPER COMPD PASONG TAMO QUEZON CITY
# Check: 876
# 18B OZAMIS ST   STA CRUZ  QUEZON CITY
# Check: 878
# 18C SNT JOSEPH ST MILTON HILLS SUBD NEW ERA (CONSTITUTION HILLS) QUEZON CITY
# Check: 879
# 18C SNT JOSEPH ST MILTON HILLS SUBD NEW ERA (CONSTITUTION HILLS) QUEZON CITY
# Now on: 900
# Check: 906
# 192 FATIMA ST POOK DAGOHOY UP CAMPUS QUEZON CITY
# Check: 938
# 19C LAGUNA ST RAMON MAGSAYSAY QUEZON CITY
# Check: 939
# 19C NORTH DIVERSION ROAD UNANG SIGAW BALINTAWAK QUEZON CITY
# Check: 971
# 201 NEW ORLEANS ST  UPPER BERNARDO PASONG TAMO QUEZON CITY NCR
# Check: 975
# 202 2ND FLOOR KY BLDG I BANAHAW ST KAUNLARAN QUEZON CITY
# Check: 977
# 203 BLK 6 DAMAYANG LAGI QUEZON CITY NCR
# Check: 979
# 203 K CONSEPCION ST SANTOLAN QUEZON CITY
# Check: 980
# 203 K CONSEPCION ST SANTOLAN QUEZON CITY
# Check: 995
# 207 SECOND NORTH 2906 KING SOLOMON ST AREA C
# Check: 996
# 207 UNIT 5 ADARNA STREET PUROK 6 COMMONWEALTH QUEZON CITY
# Now on: 1000
# Check: 1042
# 216A WOODRIDGE BLDG SOFIA BELLEVUE MATANDANG BALARA QUEZON CITY
# Check: 1057
# 22 BLK 2 BRCELONA ST PH 2 VILLA OLYMPIA GULOD QUEZON CITY
# Now on: 1100
# Check: 1187
# 27 NUPAX CMPD BAGBAG NOVALICHES QUEZON CITY
# Check: 1194
# 275 J P RIZAL ST BAGONG SILANGAN QUEZON CITY
# Now on: 1200
# Check: 1225
# 293 105 ST SOLDIERS VILLAGE SANTA LUCIA QUEZON CITY
# Check: 1254
# 3 CADMIUM ST FILINVEST 2 QUEZON CITY
# Now on: 1300
# Check: 1358
# 35-D PROJECT 4 ESCOPA I QUEZON CITY NCR
# Check: 1375
# 373 QUIRINO HI WAY QUEZON CITY
# Now on: 1400
# Check: 1410
# 3RD FLOOR 61 SAN ILDEFONSO DRIVE TORNES VILLAGE NAGKAISANG NAYON QUEZON CITY
# Check: 1457
# 426 INOCENCIO BGY 93 TONDO NCR  CITY OF MANILA
# Check: 1462
# 42-E KAUNLARAN ST  KAINGIN BUKID APOLONIO SAMSON QUEZON CITY NCR
# Check: 1487
# 44-A STA  BARBARA ST  BRGY  GULOD NOVA QC  GULOD  NOVALIXHES QUEZON CITY  N/A
# Now on: 1500
# Check: 1531
# 4917 13TH ST  STO  NIÑO PQUE   STO NINO  PQUE CITY
# Check: 1534
# 4985 14TH ST  A  STO  NIÑO PQUE   STO NINO  PQUE CITY
# Check: 1568
# 504 OFFICERS ROW CAMACHO ST AREVALO AVE CAMP AGUINALDO QUEZON CITY
# Now on: 1600
# Check: 1626
# 5-A AREVALO COMPD  GRANTS ST   PROJ  8  SANGANDAAN  QUEZON CITY  N/A
# Check: 1650
# 607 GEN MALVAR BAGONG SILANGAN QUEZON CITY
# Check: 1669
# 63 L-1 STO  NINO 1 CSJDM  BULACAN
# Now on: 1700
# Check: 1742
# 71 L 5 AB YUAN ST  PHASE 8  NORTH FAIRVIEW  QUEZON CITY  CITY OF MANILA
# Now on: 1800
# Now on: 1900
# Check: 1908
# 9-J L PASCO ST LIBIS QUEZON CITY  N/A  N/A  N/A
# Check: 1963
# A MAARALIN STREET EL RIO VISTA  CENTRAL QUEZON CITY
# Check: 1997
# A SAN ANTONIO SUBD  DAMONG MALIIT NOVA QC  DAMONG MALIIT  NOVALICHES  QUEZON CITY  N/A
# Now on: 2000
# Check: 2009
# A SOUTH GATE BALARA PANSOL QUEZON CITY
# Now on: 2100
# Check: 2100
# ALLADO ST SAN ANTONIO SUBD DAMONG MALIIT NAGKAISANG NAYON NOVALICHES QUEZON CITY
# Check: 2176
# AREA 06 SITIO CABUYAO SAUYO QC
# Check: 2185
# AREA 4 BAYANIHAN ST   TALANAY BATASAN HILLS QUEZON CITY NCR
# Now on: 2200
# Check: 2222
# ASTON ST NORTH FAIRVIEW QUEZON CITY
# Now on: 2300
# Check: 2309
# B OZAMIS ST  SANTA CRUZ QUEZON CITY NCR
# Check: 2313
# B PAGASA QUEZON CITY
# Now on: 2400
# Check: 2441
# B58 L9 PH12 RIVERSIDE CALOOCAN CITY THIRD DIST
# Check: 2442
# B59 BRIMLEY ST FAIRVILLE HOMES NORTH FAIRVIEW QUEZON CITY
# Check: 2445
# B59 L41 GRANDRIVERSIDE  PASCAM1  GENTRIAS CAVITE
# Check: 2451
# B70 YUAN ST PH8 NORTH FAIRVIEW QUEZON CITY
# Check: 2454
# B7-L14/16 P1 SILVERCREEK SUBD
# Check: 2455
# B7-L22 PORTICO-I SUBD
# Now on: 2500
# Check: 2515
# BATAAN RD GARCIA HTS LUZON AVE HOLY SPIRIT QUEZON CITY
# Check: 2525
# BATINO ST  ALLEY 20  AMIHAN  QUEZON CITY  N/A
# Check: 2554
# BGY STO NIÑO MULANAY QUEZON
# Now on: 2600
# Check: 2614
# BLK 1 L 15 GK ROQUE I PASONG TAMO QUEZON CITY
# Check: 2619
# BLK 1 LOT 2 QUEENSVILLE SUBD BAGUMBONG BGY 171 CALOOCAN CITY
# Now on: 4600
# Check: 4692
# MATIN-AO PRK  PAG-ASA  SILWAY 8 POL SO COT   N/A  N/A  N/A
# Now on: 4700
# Check: 4731
# MENDOZA CMPD SAMONTE RD NAGKAISANG NAYON NOVALICHES PROPER QUEZON CITY
# Check: 4761
# MOLAVE ST NORTHVIEW II FILINVEST II QUEZON CITY
# Check: 4764
# MOLAVE ST  NORTHVIEW 2  BATASAN HILLS  QUEZON CITY   METRO MANILA
# Now on: 4800
# Check: 4831
# Ñ12 SAN JOSE VILLAGE BRGY  BAHAY TORO QC  N/A  N/A  N/A
# Check: 4890
# Ñ84-C ROAD 2 PAG-ASA QUEZON CITY
# Now on: 4900
# Check: 4903
# NAMAPA CMPD NORTH FAIRVIEW QUEZON CITY
# Check: 4905
# NANGKA ST NORTHVIEW 2 FILINVEST 2 BATASAN HILLS QUEZON CITY
# Check: 4906
# NANGKA STREET NORTHVIEW 2 FILINVEST 2 BATASAN HILLS QUEZON CITY
# Check: 4939
# NIÑO KID  CITY
# Check: 4940
# NIÑO  KID  CITY
# Check: 4981
# OAK EXT WEST FAIRVIEW QUEZON CITY
# Check: 4998
# OLYMPUS DRIVE SERRA MONTE FILINVEST 2  QUEZON CITY
# Check: 4999
# OLYMPUS DRIVE SERRA MONTE VILLAS  MONTE VILLAS  QUEZON CITY   NATIONA CAPITAL REGION
# Now on: 5000
# Check: 5000
# OMBEL ST  ROXAS DISTRICT  QUEZON CITY  N/A  N/A  N/A
# Check: 5085
# PALMA STREET FILINVEST II QUEZON CITY
# Now on: 5100
# Check: 5119
# PAWAI ST I DOÑA IMELDA QUEZON CITY
# Check: 5133
# PEARL ST NORTHVIEW I FILINVEST II BATASAN HILLS QUEZON CITY
# Check: 5185
# PINK CONDO TIERRA BELLA TANDANG SORA Q C   N/A  N/A  N/A
# Now on: 5200
# Check: 5238
# PRK 3  BALIGANG  CAMALIG ALBAY  QUEZON CITY   NATIONA CAPITAL REGION
# Check: 5273
# PUROK 9A COUNTRY HILLS LUINAB  ILIGAN CITY
# Now on: 5300
# Check: 5339
# REGINA VIL PHILAND DRIVE TANDANG SORA QUEZON CITY
# Check: 5345
# RIVERSIDE 1 DEL NACIA SAUYO QUEZON CITY
# Check: 5347
# RIVERSIDE SUBD  BALINTAWAK  N/A  N/A  N/A
# Now on: 5400
# Now on: 5500
# Now on: 5600
# Check: 5631
# SITIO GULOD KALAYAAN B BATASAN HILLS QUEZON CITY
# Check: 5644
# SITIO PALANAS VASRA QUEZON CITY
# Check: 5645
# SITIO PALANAS VASRA QUEZON CITY
# Check: 5672
# SOUTH GATE 78-A PANSOL QUEZON CITY NCR
# Now on: 5700
# Check: 5706
# ST  LOUIS COMP  6  BAESA  QUEZON CITY  N/A  N/A  N/A
# Check: 5715
# STA CLARA SAINT JAMES SUB NOVALICHES NAGKAISANG NAYON QUEZON CITY
# Check: 5740
# STO NIÑO MULANAY QUEZON
# Check: 5741
# STO NIÑO ST B BAYAN QUEZON CITY
# Check: 5753
# STO TOMAS LIBIS BAGUMBAYAN QUEZON CITY
# Now on: 5800
# Check: 5875
# TURQUOISE ST GEMSVILLE SUBD LAHUG (POB ) CEBU CITY CEBU
# Now on: 5900
# Check: 5902
# UNIT 1 4TH FLR SOLEDAD BLDG 94 BANAWE ST QUEZON CITY
# Check: 5911
# UNIT 10A BLDG 3 BLK 3 GOLDMINE INT NOVALICHES NAGKAISANG NAYON QUEZON CITY
# Check: 5915
# UNIT 114 APARTELLE BLDG QUIRINO HI WAY PASONG PUTIK QUEZON CITY
# Check: 5931
# UNIT 2 MARCELESTER CTR KATIPUNAN AVE COR WEST BERKELEY ST CALIFORNIA VILLAGE SN BARTOLOME NOVALICHES PROPER QUEZON CITY
# Check: 5937
# UNIT 22-20 NEOVISTA HOMES BAGUMBONG NOVALICHES PROPER QUEZON CITY
# Check: 5963
# UNIT 3D APT VERLAN SANTIAGO ST   PUTOL VISTA VERDE
# Check: 5967
# UNIT 4 DELA PAZ APARTMENT RIVERA AVENUE RIVERA VILLAGE JP LAUREL DAVAO CITY
# Check: 5968
# UNIT 4 ILANG ILANG ILANG ST
# Now on: 6000
# Check: 6021
# UNIT A202A EC PUEBLO 1 44 KING CHRISTIAN KINGSPOINT NOVALICHES BAGBAG QUEZON CITY
# Check: 6037
# UNIT H MELODY TOWNHOMES  LA GUARDIA EXT   LAHUG  CEBU CITY  CEBU PROV
# Now on: 6100
# Check: 6103
# VISAYAS EXTN PINGKIAN 3 ZONE 3 PASONG TAMO QUEZON CITY
# Check: 6106
# VISTA HERMOSA   SAN MATEO RIZAL  SAN MATEO RIZAL  QUEZON CITY   NATIONA CAPITAL REGION
# Check: 6153
# YANEZA DRIVE SERRA MONTE VILLAS FILINVEST 2 BATASAN HILLS QUEZON CITY
# Check: 6164
# ZARAGOSA ST   BRGY  DOÑA IMELDA  QUEZON CITY CPO  QUEZON CITY
# Check: 6167
# ZEUS DRIVE SERRA MONTEVILLAS  BRGY  BATASAN HILLS  QUEZON CITY   METRO MANILA

# %% [markdown]
# ### Check the Results – AKA Manual Encoding Part :(

# %% [markdown]
# #### Keyword Identification (Old Code, Do Not Run)

# %% [markdown]
# Description: Some addresses already have the baranggay written in them – so we don't need to search those up. Then, we identify addresses by villages/projects/roads which will hopefully make it easier to classify things.

# %%
def nextword(target, source, count):
    for i, w in enumerate(source):
        if w == target:
            try:
                return source[i+count]
            except:
                return ' '

key = []
entry = []
for item in fix['lst']:
    keys = set(item).intersection(['BGY','BRGY','VILLAGE','SUBD','HILLS','HOMES','HEIGHTS','HTS','PROJ','PROJECT',
                                   'BLDG','CONDO','ST','STR','RD','AVE','STREET','ROAD','AVENUE','DRIVE','SCT',
                                   'SCOUT','EXT','EXTN','EXTENSION','APT'])
    if len(keys) == 0:
        key.append('None')
        entry.append(' '.join(item)) 
    #Baranggay
    if 'BGY' in keys:
        key.append('Barangay')
        entry.append(nextword('BGY',item,1))
    elif 'BRGY' in keys:
        key.append('Barangay')
        entry.append(nextword('BRGY',item,1))
    #Village/Subdivision
    elif 'VILLAGE' in keys:
        key.append('Village')
        entry.append(nextword('VILLAGE',item,-1))
    elif 'SUBD' in keys:
        key.append('Village')
        entry.append(nextword('SUBD',item,-1))
    elif 'HILLS' in keys:
        key.append('Village')
        entry.append(nextword('HILLS',item,-1))
    elif 'HOMES' in keys:
        key.append('Village')
        entry.append(nextword('HOMES',item,-1))
    elif 'HEIGHTS' in keys:
        key.append('Village')
        entry.append(nextword('HEIGHTS',item,-1))
    elif 'HTS' in keys:
        key.append('Village')
        entry.append(nextword('HTS',item,-1))
    #Project
    elif 'PROJ' in keys:
        key.append('Project')
        entry.append(nextword('PROJ',item,1))
    elif 'PROJECT' in keys:
        key.append('Project')
        entry.append(nextword('PROJECT',item,1))
    #Road
    elif 'ST' in keys:
        key.append('Road')
        entry.append(nextword('ST',item,-1))
    elif 'RD' in keys:
        key.append('Road')
        entry.append(nextword('RD',item,-1))
    elif 'STR' in keys:
        key.append('Road')
        entry.append(nextword('STR',item,-1))
    elif 'STREET' in keys:
        key.append('Road')
        entry.append(nextword('STREET',item,-1))
    elif 'DRIVE' in keys:
        key.append('Road')
        entry.append(nextword('DRIVE',item,-1))
    elif 'EXT' in keys:
        key.append('Road')
        entry.append(nextword('EXT',item,-1))
    elif 'EXTENSION' in keys:
        key.append('Road')
        entry.append(nextword('EXTENSION',item,-1))
    elif 'EXTN' in keys:
        key.append('Road')
        entry.append(nextword('EXTN',item,-1))
    elif 'SCT' in keys:
        key.append('Road')
        entry.append(nextword('SCT',item,1))
    elif 'SCOUT' in keys:
        key.append('Road')
        entry.append(nextword('SCOUT',item,1))
    
    #Building
    elif 'BLDG' in keys:
        key.append('Building')
        entry.append(nextword('BLDG',item,-1))
    elif 'CONDO' in keys:
        key.append('Building')
        entry.append(nextword('CONDO',item,-1))
    elif 'APT' in keys:
        key.append('Building')
        entry.append(nextword('APT',item,-1))
    elif 'RESIDENCE' in keys:
        key.append('Building')
        entry.append(nextword('RESIDENCE',item,-1))
    elif 'RESIDENCES' in keys:
        key.append('Building')
        entry.append(nextword('RESIDENCES',item,-1))

    #Avenue
    elif 'AVE' in keys:
        key.append('Avenue')
        entry.append(nextword('AVE',item,-1))
    elif 'AVENUE' in keys:
        key.append('Avenue')
        entry.append(nextword('AVENUE',item,-1))
    elif 'ROAD' in keys:
        key.append('Avenue')
        entry.append(nextword('ROAD',item,-1))
    else:
        pass

fix['key'] = key
fix['entry'] = entry

# %% [markdown]
# The list "l" contains indices of addresses with no baranggays yet.

# %%
l=[i for i,v in enumerate(fix['bgy']) if v == None]

# %% [markdown]
# #### Checking for Baranggays

# %% [markdown]
# Description: Follow the code below to manually encode!

# %%
#Shows the rows for missing barangays
fix.iloc[l,:][fix['key']=='Barangay'].head(2)
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                           stripaddress  \
# 11   004 ZAMBOANGA ST., BAI COMPOUND, BRGY. VASRA, ...
# 215       1064 A CULLEJON LIWANAG BGY 215 TONDO MANILA
#
#                                                   edit  \
# 11   004 ZAMBOANGA ST   BAI COMPOUND  BRGY  VASRA  ...
# 215       1064 A CULLEJON LIWANAG BGY 215 TONDO MANILA
#
#                                                    lst      lat      lng  \
# 11   [004, ZAMBOANGA, ST, BAI, COMPOUND, BRGY, VASR...  6.92144  122.079
# 215  [1064, A, CULLEJON, LIWANAG, BGY, 215, TONDO, ...  45.6696  9.70363
#
#                                                    add       key  entry  \
# 11                              Zamboanga, Philippines  Barangay  VASRA
# 215  Il Caravaggio Orio al Serio International Airp...  Barangay    215
#
#                                       pt    bgy
# 11         POINT (122.0790267 6.9214424)  Vasra
# 215  POINT (9.7036313 45.66957070000001)    215

# %%
#Gets indices of missing barangays
missBrgy = fix.iloc[l,:][fix['key']=='Barangay']
missBrgy = missBrgy.index.tolist()
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
#Input the list of barangays in "brgys"
counter = 0
brgys = ['Vasra','215','E. Rodriguez','93','Gulod','Santo Nino','171','Pury','San Antonio',
         'Fortune','Bagong Silang','Bahay Toro','Dona Imelda','Batasan Hills']
for i in missBrgy:
    fix['bgy'][i] = brgys[counter]
    counter += 1

# %% [markdown]
# #### Checking for Villages

# %%
missVill = fix.iloc[l,:][fix['key']=='Village']
missVill = missVill.index.tolist()
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fix.iloc[l,:][fix['key']=='Village']
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                            stripaddress  \
# 659   15 BLK 52 PANTOMINA MAYOR ST LAGRO SUBD NOVALI...
# 878   18C SNT JOSEPH ST MILTON HILLS SUBD NEW ERA (C...
# 879   18C SNT JOSEPH ST MILTON HILLS SUBD NEW ERA (C...
# 1225  293 105 ST SOLDIERS VILLAGE SANTA LUCIA QUEZON...
# 1410  3RD FLOOR 61 SAN ILDEFONSO DRIVE TORNES VILLAG...
# 1997  A SAN ANTONIO SUBD. DAMONG MALIIT NOVA QC, DAM...
# 2100  ALLADO ST SAN ANTONIO SUBD DAMONG MALIIT NAGKA...
# 2185  AREA 4 BAYANIHAN ST., TALANAY BATASAN HILLS QU...
# 2442  B59 BRIMLEY ST FAIRVILLE HOMES NORTH FAIRVIEW ...
# 2454                     B7-L14/16 P1 SILVERCREEK SUBD.
# 2455                             B7-L22 PORTICO-I SUBD.
# 2515  BATAAN RD GARCIA HTS LUZON AVE HOLY SPIRIT QUE...
# 2635  BLK 1 LOT 9 KASIYAHAN ST, BATASAN HILLS QUEZON...
# 2667  BLK 13 LOT 15 SOLDIERS HILLS III TALA QUEZON CITY
# 2673  BLK 14 LOT 36 SIEERA VISTA SUBD NOVA QUEZON CI...
# 2691         BLK 1A GALLEY ST BATASAN HILLS QUEZON CITY
# 2749  BLK 2A LOT 33 PALMERA HOMES SUBD NOVALICHES EA...
# 2792  BLK 31 LOT 55 SALUBONG ST LAGRO SUBD NOVALICHE...
# 2965  BLOCK 28 LOT 2 DIEGO SILANG ST NCE 1 BATASAN H...
# 3224  COMPOSTELA ST FILINVEST 2 BATASAN HILLS QUEZON...
# 3311  D&A VICENTE VILLAGE EXT. BAGONG SILANGAN QUEZO...
# 3391  DIAMOND ST. NORTHVIEW 1, BATASAN HILLS, QUEZON...
# 2455                                   None  None
# 2515         POINT (120.4818446 14.6416842)  None
# 2635         POINT (121.1074655 14.6797618)  None
# 2667         POINT (121.0782249 14.7646773)  None
# 2673         POINT (121.1270683 14.6338387)  None
# 2691         POINT (121.1074655 14.6797618)  None
# 2749                                   None  None
# 2792                                   None  None
# 2965                                   None  None
# 3224         POINT (121.1074655 14.6797618)  None
# 3311            POINT (-95.712891 37.09024)  None
# 3391         POINT (121.1074655 14.6797618)  None
# 3524         POINT (121.1074655 14.6797618)  None
# 3546         POINT (120.9363889 16.1308333)  None
# 3679        POINT (-122.2015159 47.6101497)  None
# 3681         POINT (121.1074655 14.6797618)  None
# 3682         POINT (121.1074655 14.6797618)  None
# 3683         POINT (121.1074655 14.6797618)  None
# 3772         POINT (121.1105313 14.6883058)  None
# 4074         POINT (121.1144731 14.6847098)  None
# 4227         POINT (121.1074655 14.6797618)  None
# 4764         POINT (121.1074655 14.6797618)  None
# 4905         POINT (121.1074655 14.6797618)  None
# 4906         POINT (121.1074655 14.6797618)  None
# 5133         POINT (121.1074655 14.6797618)  None
# 5273  POINT (124.2649727 8.237762099999999)  None
# 5347        POINT (-117.3754942 33.9806005)  None
# 5631         POINT (120.9984454 14.7775863)  None
# 5875         POINT (123.9018023 10.3248149)  None
# 5931        POINT (-122.2985808 37.8743703)  None
# 5937         POINT (121.0105596 14.7510655)  None
# 5967           POINT (125.619725 7.0980607)  None
# 6153         POINT (121.1105313 14.6883058)  None

# %%
fix.loc[6153,]['edit']
# Out:
# 'YANEZA DRIVE SERRA MONTE VILLAS FILINVEST 2 BATASAN HILLS QUEZON CITY'

# %%
counter = 0
vills = ['Greater Lagro','Culiat','Culiat','Santa Lucia','Nagkaisang Nayon',
         'Nagkaisang Nayon','Nagkaisang Nayon','Batasan Hills','Greater Lagro',
         'Bocohan','Lumbia','Holy Spirit','Batasan Hills','180','Nagkaisang Nayon',
          'Batasan Hills','Santa Monica','Greater Lagro','Nagkaisang Nayon',
          'Batasan Hills','Bagong Silangan','Batasan Hills','Batasan Hills',
          'Holy Spirit','Balintawak','Batasan Hills','Batasan Hills','Batasan Hills',
          'Batasan Hills','Batasan Hills','Batasan Hills','Batasan Hills',
          'Batasan Hills','Batasan Hills','Batasan Hills','Luinab','Balintawak',
          'Batasan Hills','Lahug','San Bartolome','171','164','Batasan Hills']
for i in missVill:
    fix['bgy'][i] = vills[counter]
    counter += 1

# %% [markdown]
# #### Checking for Projects

# %%
missProj = fix.iloc[l,:][fix['key']=='Project']
missProj = missProj.index.tolist()
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fix.iloc[l,:][fix['key']=='Project']
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                            stripaddress  \
# 307       116 BAGUIO CMPD ROAD 20 PROJECT 8 QUEZON CITY
# 1358            35-D PROJECT 4 ESCOPA I QUEZON CITY NCR
# 1626  5-A AREVALO COMPD. GRANTS ST., PROJ. 8, SANGAN...
# 2835    BLK 48 LOT 35 PROJ 4 ESCOPA III QUEZON CITY NCR
# 3076  C T MASCARDO ST VILLA MARIA CLARA PROJ 4 QUEZO...
# 3097          CAIRO ST STA RITA VILL PROJ 8 QUEZON CITY
# 3536  ERVIE BEN NOBLEZA 1009 AURORA BLVD PROJECT 3 D...
# 4461                    LUCENA ST PROJECT 6 QUEZON CITY
#
#                                                    edit  \
# 307       116 BAGUIO CMPD ROAD 20 PROJECT 8 QUEZON CITY
# 1358            35-D PROJECT 4 ESCOPA I QUEZON CITY NCR
# 1626  5-A AREVALO COMPD  GRANTS ST   PROJ  8  SANGAN...
# 2835    BLK 48 LOT 35 PROJ 4 ESCOPA III QUEZON CITY NCR
# 3076  C T MASCARDO ST VILLA MARIA CLARA PROJ 4 QUEZO...
# 3097          CAIRO ST STA RITA VILL PROJ 8 QUEZON CITY
# 3536  ERVIE BEN NOBLEZA 1009 AURORA BLVD PROJECT 3 D...
# 4461                    LUCENA ST PROJECT 6 QUEZON CITY
#
#                                                     lst      lat      lng  \
# 307   [116, BAGUIO, CMPD, ROAD, 20, PROJECT, 8, QUEZ...  16.4023  120.596
# 1358   [35-D, PROJECT, 4, ESCOPA, I, QUEZON, CITY, NCR]     None     None
# 1626  [5-A, AREVALO, COMPD, GRANTS, ST, PROJ, 8, SAN...   41.059 -4.71874
# 2835  [BLK, 48, LOT, 35, PROJ, 4, ESCOPA, III, QUEZO...  46.3826 -63.0314
# 3076  [C, T, MASCARDO, ST, VILLA, MARIA, CLARA, PROJ...  41.6032 -73.0877
# 3097  [CAIRO, ST, STA, RITA, VILL, PROJ, 8, QUEZON, ...  30.0444  31.2357
# 3536  [ERVIE, BEN, NOBLEZA, 1009, AURORA, BLVD, PROJ...  54.9655 -5.12506
# 4461             [LUCENA, ST, PROJECT, 6, QUEZON, CITY]  13.9414  121.623
#
#                                    add      key entry  \
# 307       Baguio, Benguet, Philippines  Project     8
# 1358                              None  Project     4
# 1626       05200 Arévalo, Ávila, Spain  Project     8
# 2835                Lot 35, PE, Canada  Project     4
# 3076                  Connecticut, USA  Project     4
# 3097   Cairo, Cairo Governorate, Egypt  Project     8
# 3536      Ervie, Stranraer DG9 0RB, UK  Project     3
# 4461  Lucena, 4301 Quezon, Philippines  Project     6
#
#                                   pt   bgy
# 307   POINT (120.5960071 16.4023332)  None
# 1358                            None  None
# 1626    POINT (-4.7187424 41.058981)  None
# 2835  POINT (-63.0314308 46.3826063)  None
# 3076   POINT (-73.087749 41.6032207)  None
# 3097   POINT (31.2357116 30.0444196)  None
# 3536     POINT (-5.125062 54.965514)  None
# 4461  POINT (121.6234471 13.9413957)  None

# %%
counter = 0
projs = ['Bahay Toro','Escopa I','Sangandaan','Escopa III','Milagrosa','Bahay Toro',
         'Duyan Duyan','Project 6']
for i in missProj:
    fix['bgy'][i] = projs[counter]
    counter += 1

# %% [markdown]
# #### Checking for Roads

# %%
missRoad = fix.iloc[l,:][fix['key']=='Road']
missRoad = missRoad.index.tolist()
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fix.iloc[l,:][fix['key']=='Road'][70:]
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                            stripaddress  \
# 6103  VISAYAS EXTN PINGKIAN 3 ZONE 3 PASONG TAMO QUE...
#
#                                                    edit  \
# 6103  VISAYAS EXTN PINGKIAN 3 ZONE 3 PASONG TAMO QUE...
#
#                                                     lst lat    lng  \
# 6103  [VISAYAS, EXTN, PINGKIAN, 3, ZONE, 3, PASONG, ...  11  123.5
#
#                        add   key    entry                pt   bgy
# 6103  Visayas, Philippines  Road  VISAYAS  POINT (123.5 11)  None

# %%
fix.loc[5963,]['edit']
# Out:
# 'UNIT 3D APT VERLAN SANTIAGO ST   PUTOL VISTA VERDE'

# %%
counter = 0
roads = ['Payatas','Batasan Hills','Quirino 2B','Bagong Silangan','San Antonio',
         'Batasan Hills','Sauyo','Duyan-Duyan','177','175',
         '177','Batasan Hills','Santa Cruz','Payatas','Bago Bantay',
         'Don Bosco','Kaunlaran','Santolan','Santolan','Camp Aguinaldo',
         'Malanday','Gulod','Bagong Silangan','Bagong Silangan','Balintawak',
         'Santo Nino','Santo Nino','Camp Aguinaldo','North Fairview','Libis',
         'Central','North Fairview','Santa Cruz','North Fairview','Amihan',
         'Holy Spirit','Westt Fairview','Kaligayahan','Greater Lagro','North Fairview',
         'North Fairview','Tatalon','Central','Santa Cruz','Manresa',
         'Quirino 3A','Llano','Bagbag','Payatas','Santa Lucia',
         'Libis','North Fairview','Sangandaan','San Bartolome','Commonwealth',
         'Nagkaisang Nayon','Batasan Hills','West Fairview','Batasan Hills','Batasan Hills',
         'Roxas','Batasan Hills','Dona Imelda','Tandang Sora','Baesa',
         '177','Santa Mesa Heights','Llano','Commonwealth','Lahug',
         'Pasong Tamo'
        ]
for i in missRoad:
    fix['bgy'][i] = roads[counter]
    counter += 1

# %% [markdown]
# #### Checking for Buildings

# %%
missBuil = fix.iloc[l,:][fix['key']=='Building']
missBuil = missBuil.index.tolist()
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fix.iloc[l,:][fix['key']=='Building']
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                            stripaddress  \
# 1042  216A WOODRIDGE BLDG SOFIA BELLEVUE MATANDANG B...
# 5185  PINK CONDO TIERRA BELLA TANDANG SORA Q.C., N/A...
# 5911  UNIT 10A BLDG 3 BLK 3 GOLDMINE INT NOVALICHES ...
# 5915  UNIT 114 APARTELLE BLDG QUIRINO HI WAY PASONG ...
#
#                                                    edit  \
# 1042  216A WOODRIDGE BLDG SOFIA BELLEVUE MATANDANG B...
# 5185  PINK CONDO TIERRA BELLA TANDANG SORA Q C   N/A...
# 5911  UNIT 10A BLDG 3 BLK 3 GOLDMINE INT NOVALICHES ...
# 5915  UNIT 114 APARTELLE BLDG QUIRINO HI WAY PASONG ...
#
#                                                     lst      lat      lng  \
# 1042  [216A, WOODRIDGE, BLDG, SOFIA, BELLEVUE, MATAN...   41.747 -88.0503
# 5185  [PINK, CONDO, TIERRA, BELLA, TANDANG, SORA, Q,...     None     None
# 5911  [UNIT, 10A, BLDG, 3, BLK, 3, GOLDMINE, INT, NO...  14.7625  121.031
# 5915  [UNIT, 114, APARTELLE, BLDG, QUIRINO, HI, WAY,...  14.8138  121.072
#
#                                                     add       key      entry  \
# 1042                                 Woodridge, IL, USA  Building  WOODRIDGE
# 5185                                               None  Building       PINK
# 5911       Block 3, Caloocan, Metro Manila, Philippines  Building        10A
# 5915  Quirino Hwy, San Jose del Monte City, Bulacan,...  Building  APARTELLE
#
#                                   pt   bgy
# 1042  POINT (-88.0503406 41.7469749)  None
# 5185                            None  None
# 5911  POINT (121.0307651 14.7625237)  None
# 5915  POINT (121.0723104 14.8138076)  None

# %%
fix.loc[5911,]['edit']
# Out:
# 'UNIT 10A BLDG 3 BLK 3 GOLDMINE INT NOVALICHES NAGKAISANG NAYON QUEZON CITY'

# %%
counter = 0
builds = ['Matandang Balara','Tandang Sora','Nagkaisang Nayon','Pasong Tamo'
        ]
for i in missBuil:
    fix['bgy'][i] = builds[counter]
    counter += 1

# %% [markdown]
# #### Checking for Avenues

# %%
missAves = fix.iloc[l,:][fix['key']=='Avenue']
missAves = missAves.index.tolist()
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fix.iloc[l,:][fix['key']=='Avenue']
# Out:
# /Users/lorenzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                            stripaddress  \
# 939   19C NORTH DIVERSION ROAD UNANG SIGAW BALINTAWA...
# 4890                   Ñ84-C ROAD 2 PAG-ASA QUEZON CITY
#
#                                                    edit  \
# 939   19C NORTH DIVERSION ROAD UNANG SIGAW BALINTAWA...
# 4890                   Ñ84-C ROAD 2 PAG-ASA QUEZON CITY
#
#                                                     lst     lat      lng  \
# 939   [19C, NORTH, DIVERSION, ROAD, UNANG, SIGAW, BA...  14.725  120.984
# 4890            [Ñ84-C, ROAD, 2, PAG-ASA, QUEZON, CITY]    None     None
#
#                                                add     key      entry  \
# 939   19 E1, Valenzuela, 1447 Bulacan, Philippines  Avenue  DIVERSION
# 4890                                          None  Avenue      Ñ84-C
#
#                                 pt   bgy
# 939   POINT (120.984126 14.725003)  None
# 4890                          None  None

# %%
counter = 0
aves = ['Balintawak','Bagong Pagasa'
        ]
for i in missAves:
    fix['bgy'][i] = aves[counter]
    counter += 1

# %% [markdown]
# #### Everything Else

# %% [markdown]
# Now we check for all those that still have not been classified, and do it super manually. We first update the list of missing entries 'l'.

# %%
l=[i for i,v in enumerate(fix['bgy']) if v == None]
fix.iloc[l,:]
# Out:
#                                            stripaddress  \
# 4                 001 LEYTE GROUP 7 PAYATAS QUEZON CITY
# 93    079 GINUNTUANG LANDAS FOREST HILL SANTA MONICA...
# 296                                       1141 SANTA RC
# 977             203 BLK 6 DAMAYANG LAGI QUEZON CITY NCR
# 1187        27 NUPAX CMPD BAGBAG NOVALICHES QUEZON CITY
# 1375                     373 QUIRINO HI WAY QUEZON CITY
# 1650         607 GEN MALVAR BAGONG SILANGAN QUEZON CITY
# 1669                  63 L-1 STO. NINO 1 CSJDM, BULACAN
# 2009             A SOUTH GATE BALARA PANSOL QUEZON CITY
# 2176                     AREA 06 SITIO CABUYAO SAUYO QC
# 2313                               B PAGASA QUEZON CITY
# 2441    B58 L9 PH12 RIVERSIDE CALOOCAN CITY THIRD DIST.
# 2445   B59 L41 GRANDRIVERSIDE.,PASCAM1, GENTRIAS,CAVITE
# 2614      BLK 1 L 15 GK ROQUE I PASONG TAMO QUEZON CITY
# 2715  BLK 2 LOT 9, TIERRA NOVA 2-C,, BAGUMBONG,, QUE...
# 2954           BLK64 LOT1 GREATER LAGRO QUEZON CITY NCR
# 2967  BLOCK 5 LOT 31 VILLA ESPANA 2 TATALON QUEZON C...
# 2974                          BLVD., KIDAPAWAN CITY COT
# 3121  CAMP SECURITY AND ESCORT UNIT OFFICE KIANGAN H...
# 3966  JALAN BANDAROLO NO.39B PANDANG WEST SUMATRA IN...
# 3967                                              JAPAN
# 4162                KIANGAN HALL CAMP CRAME QUEZON CITY
# 4376  LOT 1 BLK 3 UNION VILL BO BAGUMBONG NOVA. QUEZ...
# 4429                       LOT 99 LIBIS QUEZON CITY NCR
# 4692  MATIN-AO PRK. PAG-ASA, SILWAY 8,POL.SO.COT., N...
# 4903             NAMAPA CMPD NORTH FAIRVIEW QUEZON CITY
# 4939                                     NIÑO KID. CITY
# 4940                                    NIÑO, KID. CITY
# 5238  PRK 3, BALIGANG, CAMALIG ALBAY, QUEZON CITY , ...
# 5345            RIVERSIDE 1 DEL NACIA SAUYO QUEZON CITY
# 5644                    SITIO PALANAS VASRA QUEZON CITY
# 5645                    SITIO PALANAS VASRA QUEZON CITY
# 5672             SOUTH GATE 78-A PANSOL QUEZON CITY NCR
# 5715  STA CLARA SAINT JAMES SUB NOVALICHES NAGKAISAN...
# 5740                            STO NIÑO MULANAY QUEZON
# 5753             STO TOMAS LIBIS BAGUMBAYAN QUEZON CITY
# 6021  UNIT A202A EC PUEBLO 1 44 KING CHRISTIAN KINGS...
# 6106  VISTA HERMOSA , SAN MATEO RIZAL, SAN MATEO RIZ...
#
#                                                    edit  \
# 4                 001 LEYTE GROUP 7 PAYATAS QUEZON CITY
# 93    079 GINUNTUANG LANDAS FOREST HILL SANTA MONICA...
# 296                                       1141 SANTA RC
# 977             203 BLK 6 DAMAYANG LAGI QUEZON CITY NCR
# 1187        27 NUPAX CMPD BAGBAG NOVALICHES QUEZON CITY
# 1375                     373 QUIRINO HI WAY QUEZON CITY
# 1650         607 GEN MALVAR BAGONG SILANGAN QUEZON CITY
# 1669                  63 L-1 STO  NINO 1 CSJDM  BULACAN
# 2009             A SOUTH GATE BALARA PANSOL QUEZON CITY
# 2176                     AREA 06 SITIO CABUYAO SAUYO QC
# 2313                               B PAGASA QUEZON CITY
# 2441    B58 L9 PH12 RIVERSIDE CALOOCAN CITY THIRD DIST
# 2445   B59 L41 GRANDRIVERSIDE  PASCAM1  GENTRIAS CAVITE
# 2614      BLK 1 L 15 GK ROQUE I PASONG TAMO QUEZON CITY
# 2715  BLK 2 LOT 9  TIERRA NOVA 2-C   BAGUMBONG   QUE...
# 2954           BLK64 LOT1 GREATER LAGRO QUEZON CITY NCR
# 2967  BLOCK 5 LOT 31 VILLA ESPANA 2 TATALON QUEZON C...
# 2974                          BLVD   KIDAPAWAN CITY COT
# 3121  CAMP SECURITY AND ESCORT UNIT OFFICE KIANGAN H...
# 3966  JALAN BANDAROLO NO 39B PANDANG WEST SUMATRA IN...
# 3967                                              JAPAN
# 4162                KIANGAN HALL CAMP CRAME QUEZON CITY
# 4376  LOT 1 BLK 3 UNION VILL BO BAGUMBONG NOVA  QUEZ...
# 4429                       LOT 99 LIBIS QUEZON CITY NCR
# 4692  MATIN-AO PRK  PAG-ASA  SILWAY 8 POL SO COT   N...
# 4903             NAMAPA CMPD NORTH FAIRVIEW QUEZON CITY
# 4939                                     NIÑO KID  CITY
# 4940                                    NIÑO  KID  CITY
# 5238  PRK 3  BALIGANG  CAMALIG ALBAY  QUEZON CITY   ...
# 5345            RIVERSIDE 1 DEL NACIA SAUYO QUEZON CITY
# 5644                    SITIO PALANAS VASRA QUEZON CITY
# 5645                    SITIO PALANAS VASRA QUEZON CITY
# 5672             SOUTH GATE 78-A PANSOL QUEZON CITY NCR
# 5715  STA CLARA SAINT JAMES SUB NOVALICHES NAGKAISAN...
# 5740                            STO NIÑO MULANAY QUEZON
# 5753             STO TOMAS LIBIS BAGUMBAYAN QUEZON CITY
# 6021  UNIT A202A EC PUEBLO 1 44 KING CHRISTIAN KINGS...
# 6106  VISTA HERMOSA   SAN MATEO RIZAL  SAN MATEO RIZ...
#
#                                                     lst       lat      lng  \
# 4         [001, LEYTE, GROUP, 7, PAYATAS, QUEZON, CITY]   11.3497  124.464
# 93    [079, GINUNTUANG, LANDAS, FOREST, HILL, SANTA,...   50.4738   3.3009
# 296                                   [1141, SANTA, RC]      None     None
# 977    [203, BLK, 6, DAMAYANG, LAGI, QUEZON, CITY, NCR]   14.7628  121.031
# 1187  [27, NUPAX, CMPD, BAGBAG, NOVALICHES, QUEZON, ...      None     None
# 1375              [373, QUIRINO, HI, WAY, QUEZON, CITY]   14.8138  121.072
# 1650  [607, GEN, MALVAR, BAGONG, SILANGAN, QUEZON, C...   14.6962   121.11
# 1669            [63, L-1, STO, NINO, 1, CSJDM, BULACAN]   14.8575  121.066
# 2009     [A, SOUTH, GATE, BALARA, PANSOL, QUEZON, CITY]   33.9547 -118.212
# 2176              [AREA, 06, SITIO, CABUYAO, SAUYO, QC]   14.2471  121.137
# 2313                          [B, PAGASA, QUEZON, CITY]    14.569  121.128
# 2441  [B58, L9, PH12, RIVERSIDE, CALOOCAN, CITY, THI...   33.9806 -117.375
# 2445  [B59, L41, GRANDRIVERSIDE, PASCAM1, GENTRIAS, ...   14.3735  120.891
# 2614  [BLK, 1, L, 15, GK, ROQUE, I, PASONG, TAMO, QU...   12.6679  123.988
# 2715  [BLK, 2, LOT, 9, TIERRA, NOVA, 2-C, BAGUMBONG,...   14.7795   121.05
# 2954   [BLK64, LOT1, GREATER, LAGRO, QUEZON, CITY, NCR]   15.4943  120.976
# 2967  [BLOCK, 5, LOT, 31, VILLA, ESPANA, 2, TATALON,...   7.06447  125.613
# 2974                       [BLVD, KIDAPAWAN, CITY, COT]   7.01061  125.091
# 3121  [CAMP, SECURITY, AND, ESCORT, UNIT, OFFICE, KI...   16.7712  121.099
# 3966  [JALAN, BANDAROLO, NO, 39B, PANDANG, WEST, SUM... -0.947083  100.417
# 3967                                            [JAPAN]   35.6601  139.736
# 4162         [KIANGAN, HALL, CAMP, CRAME, QUEZON, CITY]   16.7712  121.099
# 4376  [LOT, 1, BLK, 3, UNION, VILL, BO, BAGUMBONG, N...   14.7625  121.031
# 4429                [LOT, 99, LIBIS, QUEZON, CITY, NCR]   45.3926 -122.614
# 4692  [MATIN-AO, PRK, PAG-ASA, SILWAY, 8, POL, SO, C...   6.18313  125.077
# 4903      [NAMAPA, CMPD, NORTH, FAIRVIEW, QUEZON, CITY]  -13.7125  39.8322
# 4939                                  [NIÑO, KID, CITY]      None     None
# 4940                                  [NIÑO, KID, CITY]      None     None
# 5238  [PRK, 3, BALIGANG, CAMALIG, ALBAY, QUEZON, CIT...   13.1431  123.643
# 5345    [RIVERSIDE, 1, DEL, NACIA, SAUYO, QUEZON, CITY]   33.9806 -117.375
# 5644              [SITIO, PALANAS, VASRA, QUEZON, CITY]      None     None
# 5645              [SITIO, PALANAS, VASRA, QUEZON, CITY]      None     None
# 5672     [SOUTH, GATE, 78-A, PANSOL, QUEZON, CITY, NCR]   33.9547 -118.212
# 5715  [STA, CLARA, SAINT, JAMES, SUB, NOVALICHES, NA...   37.3541 -121.955
# 5740                       [STO, NIÑO, MULANAY, QUEZON]   13.5461  122.371
# 5753      [STO, TOMAS, LIBIS, BAGUMBAYAN, QUEZON, CITY]   14.1262  121.138
# 6021  [UNIT, A202A, EC, PUEBLO, 1, 44, KING, CHRISTI...   38.2544 -104.609
# 6106  [VISTA, HERMOSA, SAN, MATEO, RIZAL, SAN, MATEO...   14.6815  121.128
#
#                                                     add   key  \
# 4                                    Leyte, Philippines  None
# 93                                 59310 Landas, France  None
# 296                                                None  None
# 977        Block 6, Caloocan, Metro Manila, Philippines  None
# 1187                                               None  None
# 1375  Quirino Hwy, San Jose del Monte City, Bulacan,...  None
# 1650  607 Gen. Malvar, Quezon City, Metro Manila, Ph...  None
# 1669  Alley V, San Jose del Monte City, Bulacan, Phi...  None
# 2009                                South Gate, CA, USA  None
# 2176                       Cabuyao, Laguna, Philippines  None
# 2313             B. Pag-asa, Taytay, Rizal, Philippines  None
# 2441                                 Riverside, CA, USA  None
# 2445                 General Trias, Cavite, Philippines  None
# 2614                    Pan-Philippine Hwy, Philippines  None
# 2715  BLK 2, 2 Bagumbong Rd, Caloocan, Metro Manila,...  None
# 2954  64 Pan-Philippine Hwy, Cabanatuan City, 3100 N...  None
# 2967  2 Tatalon, Poblacion District, Quezon City, Me...  None
# 2974              Kidapawan City, Cotabato, Philippines  None
# 3121                       Kiangan, Ifugao, Philippines  None
# 3966       Padang, Padang City, West Sumatra, Indonesia  None
# 3967  5-chōme-15-5 Roppongi, Minato City, Tōkyō-to 1...  None
# 4162                       Kiangan, Ifugao, Philippines  None
# 4376  Lot 1 Block 3, Novaliches, Caloocan, Metro Man...  None
# 4429  18125 SE McLoughlin Blvd, Portland, OR 97267, USA  None
# 4692   Silway 8, Polomolok, South Cotabato, Philippines  None
# 4903                                 Namapa, Mozambique  None
# 4939                                               None  None
# 4940                                               None  None
# 5238   Baligang, Poblacion, Camalig, Albay, Philippines  None
# 5345                                 Riverside, CA, USA  None
# 5644                                               None  None
# 5645                                               None  None
# 5672                                South Gate, CA, USA  None
# 5715                               Santa Clara, CA, USA  None
# 5740                       Mulanay, Quezon, Philippines  None
# 5753                 Santo Tomas, Batangas, Philippines  None
# 6021                                    Pueblo, CO, USA  None
# 6106   Dama De Noche, St, San Mateo, Rizal, Philippines  None
#
#                                                   entry  \
# 4                 001 LEYTE GROUP 7 PAYATAS QUEZON CITY
# 93    079 GINUNTUANG LANDAS FOREST HILL SANTA MONICA...
# 296                                       1141 SANTA RC
# 977             203 BLK 6 DAMAYANG LAGI QUEZON CITY NCR
# 1187        27 NUPAX CMPD BAGBAG NOVALICHES QUEZON CITY
# 1375                     373 QUIRINO HI WAY QUEZON CITY
# 1650         607 GEN MALVAR BAGONG SILANGAN QUEZON CITY
# 1669                    63 L-1 STO NINO 1 CSJDM BULACAN
# 2009             A SOUTH GATE BALARA PANSOL QUEZON CITY
# 2176                     AREA 06 SITIO CABUYAO SAUYO QC
# 2313                               B PAGASA QUEZON CITY
# 2441     B58 L9 PH12 RIVERSIDE CALOOCAN CITY THIRD DIST
# 2445     B59 L41 GRANDRIVERSIDE PASCAM1 GENTRIAS CAVITE
# 2614      BLK 1 L 15 GK ROQUE I PASONG TAMO QUEZON CITY
# 2715  BLK 2 LOT 9 TIERRA NOVA 2-C BAGUMBONG QUEZON C...
# 2954           BLK64 LOT1 GREATER LAGRO QUEZON CITY NCR
# 2967  BLOCK 5 LOT 31 VILLA ESPANA 2 TATALON QUEZON C...
# 2974                            BLVD KIDAPAWAN CITY COT
# 3121  CAMP SECURITY AND ESCORT UNIT OFFICE KIANGAN H...
# 3966  JALAN BANDAROLO NO 39B PANDANG WEST SUMATRA IN...
# 3967                                              JAPAN
# 4162                KIANGAN HALL CAMP CRAME QUEZON CITY
# 4376  LOT 1 BLK 3 UNION VILL BO BAGUMBONG NOVA QUEZO...
# 4429                       LOT 99 LIBIS QUEZON CITY NCR
# 4692  MATIN-AO PRK PAG-ASA SILWAY 8 POL SO COT N/A N...
# 4903             NAMAPA CMPD NORTH FAIRVIEW QUEZON CITY
# 4939                                      NIÑO KID CITY
# 4940                                      NIÑO KID CITY
# 5238  PRK 3 BALIGANG CAMALIG ALBAY QUEZON CITY NATIO...
# 5345            RIVERSIDE 1 DEL NACIA SAUYO QUEZON CITY
# 5644                    SITIO PALANAS VASRA QUEZON CITY
# 5645                    SITIO PALANAS VASRA QUEZON CITY
# 5672             SOUTH GATE 78-A PANSOL QUEZON CITY NCR
# 5715  STA CLARA SAINT JAMES SUB NOVALICHES NAGKAISAN...
# 5740                            STO NIÑO MULANAY QUEZON
# 5753             STO TOMAS LIBIS BAGUMBAYAN QUEZON CITY
# 6021  UNIT A202A EC PUEBLO 1 44 KING CHRISTIAN KINGS...
# 6106  VISTA HERMOSA SAN MATEO RIZAL SAN MATEO RIZAL ...
#
#                                           pt   bgy
# 4             POINT (124.4641848 11.3496551)  None
# 93       POINT (3.3008989 50.47381600000001)  None
# 296                                     None  None
# 977           POINT (121.0314158 14.7627947)  None
# 1187                                    None  None
# 1375          POINT (121.0723104 14.8138076)  None
# 1650          POINT (121.1104401 14.6961677)  None
# 1669              POINT (121.06586 14.85751)  None
# 2009          POINT (-118.2120161 33.954737)  None
# 2176          POINT (121.1366715 14.2471423)  None
# 2313          POINT (121.1282092 14.5689974)  None
# 2441         POINT (-117.3754942 33.9806005)  None
# 2445          POINT (120.8908015 14.3735271)  None
# 2614          POINT (123.9881642 12.6679167)  None
# 2715           POINT (121.0499246 14.779497)  None
# 2954            POINT (120.975776 15.494266)  None
# 2967           POINT (125.6130403 7.0644724)  None
# 2974   POINT (125.0911341 7.010606999999999)  None
# 3121          POINT (121.0986722 16.7712337)  None
# 3966  POINT (100.417181 -0.9470831999999999)  None
# 3967          POINT (139.7355368 35.6600806)  None
# 4162          POINT (121.0986722 16.7712337)  None
# 4376          POINT (121.0312738 14.7625154)  None
# 4429         POINT (-122.6143937 45.3926291)  None
# 4692   POINT (125.0773548 6.183125299999999)  None
# 4903          POINT (39.8321879 -13.7124955)  None
# 4939                                    None  None
# 4940                                    None  None
# 5238          POINT (123.6427533 13.1430955)  None
# 5345         POINT (-117.3754942 33.9806005)  None
# 5644                                    None  None
# 5645                                    None  None
# 5672          POINT (-118.2120161 33.954737)  None
# 5715         POINT (-121.9552356 37.3541079)  None
# 5740          POINT (122.3712253 13.5460809)  None
# 5753          POINT (121.1382576 14.1262406)  None
# 6021         POINT (-104.6091409 38.2544472)  None
# 6106          POINT (121.1282969 14.6815423)  None

# %%
fix.loc[6021,]['edit']
# Out:
# 'UNIT A202A EC PUEBLO 1 44 KING CHRISTIAN KINGSPOINT NOVALICHES BAGBAG QUEZON CITY'

# %%
counter = 0
missings = ['Payatas','Santa Monica',None,'Damayang Lagi','Bagbag',
            'Talipapa','Bagong Silangan',None,'Pansol','Sauyo',
            'Bagong Pagasa','178','Pasong Camachile 1','Pasong Tamo','171',
            'Greater Lagro','Tatalon',None,'Bagong Lipunan ng Crame',
            None,None,'Bagong Lipunan ng Crame','171','Libis',
            None,'North Fairview','None','None','Baligang',
            'Sauyo','Vasra','Vasra','Pansol','Nagkaisang Nayon',
            'Santo Nino','Libis','Bagbag','Bancom Subdivision'
        ]
for i in l:
    fix['bgy'][i] = missings[counter]
    counter += 1

# %% [markdown]
# Remove all the words 'barangay' from the barangay names, update the initial dataframe called 'data', then output the final csv

# %%
import csv
fix['bgy'] = [s.replace('Barangay','') if s is not None else None for s in fix['bgy'] ]
data['Barangay'] = fix['bgy']
data.to_csv('/Users/lorenzoflores/Desktop/Dengue_Quezon_City_Baranggays.csv')
